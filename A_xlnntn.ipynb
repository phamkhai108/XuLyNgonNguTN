# %%
import requests
import re
from bs4 import BeautifulSoup

from deep_translator import GoogleTranslator

# URL của trang web
url = "https://vi.wikipedia.org/wiki/Wiki"

# Sử dụng requests để tải nội dung trang web
response = requests.get(url)

# Kiểm tra xem việc tải nội dung thành công hay không
if response.status_code == 200:
    # Lấy nội dung HTML của trang web
    html = response.text

    # Tạo một đối tượng BeautifulSoup để phân tích nội dung HTML
    soup = BeautifulSoup(html, "html.parser")

    # Tìm tất cả các thẻ <p> và lấy nội dung từ chúng
    paragraphs = soup.find_all('p')

    # Hàm loại bỏ kí tự đặc biệt và giữ lại dấu câu
    def remove_special_characters(text):
        cleaned_text = re.sub(r'[^\w\s.,?!]', '', text)
        return cleaned_text

    # Lấy văn bản từ các thẻ <p> và loại bỏ các đoạn trống
    text = '\n'.join([remove_special_characters(paragraph.get_text()).strip() for paragraph in paragraphs])


import langid

#phân tách câu bởi dấu . để xác định ngôn ngữ
sentences = text.split(". ")
# Xác định ngôn ngữ

word = []

for sentence in sentences:
    language,score = langid.classify(sentence)



# In kết quả
    print(sentence, '-', language,score)
    translation = GoogleTranslator(source=language, target='en').translate(sentence)
    word.append(translation)

with open("A.txt", "w", encoding="utf-8") as file:
    file.write(translation)

    # In kết quả dịch
    # print("Đoạn văn bản đã được dịch sang tiếng Anh là: ")
    # print(translation)


# Dịch đoạn văn bản sang tiếng Anh bằng hàm translate

# %%
import requests
import re
from bs4 import BeautifulSoup
import langid
from googletrans import Translator

# URL của trang web
url = "https://vi.wikipedia.org/wiki/Trang_Ch%C3%ADnh"

# Sử dụng requests để tải nội dung trang web
response = requests.get(url)

# Kiểm tra xem việc tải nội dung thành công hay không
if response.status_code == 200:
    # Lấy nội dung HTML của trang web
    html = response.text

    # Tạo một đối tượng BeautifulSoup để phân tích nội dung HTML
    soup = BeautifulSoup(html, "html.parser")

    # Tìm tất cả các thẻ <p> và lấy nội dung từ chúng
    paragraphs = soup.find_all('p')

    # Hàm loại bỏ kí tự đặc biệt và giữ lại dấu câu
    def remove_special_characters(text):
        cleaned_text = re.sub(r'[^\w\s.,?!]', '', text)
        return cleaned_text

    # Lấy văn bản từ các thẻ <p> và loại bỏ các đoạn trống
    text = '\n'.join([remove_special_characters(paragraph.get_text()).strip() for paragraph in paragraphs])

    # Phân tách câu bởi dấu . để xác định ngôn ngữ
    sentences = text.split(". ")

    # Xác định ngôn ngữ và dịch
    word = []
    translator = Translator()

    for sentence in sentences:
        language, score = langid.classify(sentence)

        # In kết quả
        print(sentence, '-', language, score)
        translation = translator.translate(sentence, src=language, dest='en').text
        word.append(translation)

    # Lưu nội dung đã dịch vào file "A.txt"
    with open("A.txt", "a", encoding="utf-8") as file:
        for translated_sentence in word:
            file.write(translated_sentence + '\n')

    print("Nội dung đã được lưu vào file A.txt.")
else:
    print(f"Không thể tải nội dung. Mã trạng thái: {response.status_code}")
# Out:
# Mới chọn Vụ ám sát John F - vi -122.99980664253235
# Kennedy  Hành tinh  HMS Ark Royal
# Quỹ đạo địa đồng bộ Geosynchronous orbit, viết tắt là GSO là quỹ đạo lấy Trái Đất làm tâm với chu kỳ quỹ đạo khớp với hiện tượng tự quay của Trái Đất quanh trục trong 23 giờ, 56 phút và 4 giây một ngày thiên văn - vi -1183.4739394187927
# Như vậy, đối với một quan sát viên trên bề mặt Trái Đất, sự đồng bộ chuyển động quay và chu kỳ quỹ đạo nghĩa là vật thể trên quỹ đạo địa đồng bộ sẽ trở về chính xác cùng một vị trí trên bầu trời sau một ngày - vi -1305.3148140907288
# Trong khoảng thời gian một ngày đó, vật thể đó có thể đứng yên so với bề mặt Trái Đất hoặc vạch ra một đường cong analemma phụ thuộc vào độ nghiêng và độ lệch tâm của quỹ đạo - vi -1034.143460035324
# Quỹ đạo địa đồng bộ hình tròn sẽ có độ cao không đổi 35.786 km 22.236 mi và đây cũng là bán trục lớn cho tất cả các quỹ đạo địa đồng bộ khác - vi -826.0784642696381
#  Đọc tiếp
# Mới chọn Mùa xuân nhớ Bác  Bia ở Bắc Triều Tiên  Người Neanderthal
# Năm 2011, có tổng cộng 14 đĩa đơn quán quân bảng xếp hạng trong tổng cộng tất cả 52 ngày ấn hành của Billboard Hot 100, bảng xếp hạng các đĩa đơn thành công nhất tại thị trường âm nhạc Hoa Kỳ công bố hàng tuần bởi tạp chí Billboard - vi -1594.1057150363922
# Các số liệu cho việc xếp hạng được Nielsen SoundScan tổng hợp chung dựa trên doanh số đĩa thường, nhạc số và tần suất phát trên sóng phát thanh - vi -788.0912525653839
# Trong đó, đĩa đơn Firework của nữ ca sĩ Katy Perry, đã xuất hiện trên bảng xếp hạng từ cuối năm 2010 - vi -482.69114232063293
# Năm 2011 đã có 9 nghệ sĩ lần đầu giành vị trí quán quân, kể cả là nghệ sĩ dẫn đầu hay nghệ sĩ hợp tác, bao gồm Wiz Khalifa, Adele, Pitbull, Afrojack, LMFAO, Lauren Bennett, GoonRock, Nayer và Calvin Harris - vi -877.1113357543945
#  Đọc tiếp
# Mới chọn Loài họ Chồn  Người đoạt giải Nobel Sinh lý học hoặc Y học  Quân chủ Pháp
# Từ những bài viết mới của Wikipedia
# 29 tháng 11 Ngày Quốc tế đoàn kết với nhân dân Palestine.
# Wikipedia là dự án bách khoa toàn thư mở, đa ngôn ngữ mà mọi người đều có thể tham gia đóng góp - vi -1452.846445798874
# Mục tiêu của Wikipedia là xây dựng một bách khoa toàn thư hoàn chỉnh, chính xác và trung lập.
# Sự phát triển của Wikipedia tiếng Việt phụ thuộc vào sự tham gia của bạn - vi -753.8210101127625
# Dù là tạo một bài mới, thêm nội dung, sửa lỗi chính tả hay bổ sung hình ảnh minh họa, thì bạn cũng đã góp phần xây dựng để Wikipedia tiếng Việt ngày một phát triển. - vi -885.3848361968994
# Nội dung đã được lưu vào file A.txt.
